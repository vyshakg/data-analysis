# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("makemytrip.csv",error_bad_lines=False)
# Out:
# b'Skipping line 2269: expected 33 fields, saw 52\n'

# %%
# df.drop(axis=1,inplace=True,columns=["country","in_your_room","crawl_date","highlight_value","is_value_plus","mmt_holidayiq_review_count","mmt_location_rating","qts","property_name","query_time_stamp","internet","landmark","pageurl","uniq_id","things_to_do","service_value","search_term","similar_hotel","sitename"])

# %%
pd.set_option('display.max_columns', 50)
df.head(2)
# Out:
#                 area     city country  crawl_date highlight_value  \
# 0  Hardasji Ki Magri  Udaipur   India  2016-06-21    {{facility}}
# 1      Near Nai Gaon  Udaipur   India  2016-06-21    {{facility}}
#
#                                       hotel_overview hotel_star_rating  \
# 0  |Zion Home Stay is located in a city that sets...            1 star
# 1  | Araliayas Resorts is a 3 star hotel located ...            3 star
#
#   image_urls in_your_room is_value_plus   latitude  longitude  \
# 0        NaN    {{value}}            no  24.581788  73.667805
# 1        NaN    {{value}}            no  24.544342  73.644242
#
#    mmt_holidayiq_review_count mmt_location_rating  mmt_review_count  \
# 0                         NaN                  ..               NaN
# 1                         NaN                  ..               NaN
#
#                                  mmt_review_rating  mmt_review_score  \
# 0  {{ratingCriteria.name}}{{ratingCriteria.value}}               4.5
# 1  {{ratingCriteria.name}}{{ratingCriteria.value}}               4.5
#
#                      mmt_traveller_type_review_count  mmt_tripadvisor_count  \
# 0  Families:{{ratingSummaryInfo.miscMap['family']...                    6.0
# 1  Families:{{ratingSummaryInfo.miscMap['family']...                   34.0
#
#                                              pageurl  \
# 0  http://hotelz.makemytrip.com/makemytrip/site/h...
# 1  http://hotelz.makemytrip.com/makemytrip/site/h...
#
#                                     property_address         property_id  \
# 0  Zion, F-17, Haridas Ji Ki Magri, Near Bal Vina...  201302071713316867
# 1                Udaipur-Jhadol Road , Near Nai Gaon  201312041703404727
#
#        property_name property_type  qts           query_time_stamp room_types  \
# 0     Zion Home Stay         Hotel  NaN  2016-06-21 04:06:50 +0000        NaN
# 1  Araliayas Resorts         Hotel  NaN  2016-06-21 04:06:50 +0000        NaN
#
#   site_review_count  site_review_rating    sitename state traveller_rating  \
# 0                /5                 4.5  makemytrip   NaN              NaN
# 1                /5                 4.5  makemytrip   NaN              NaN
#
#                             uniq_id
# 0  78ddf880bd7937d384ff278cc5b39d6e
# 1  9f9f9cbb2f7df8089b63d5cdeb257944

# %%
dfc=pd.read_csv("cleartrip.csv")

# %%
dfc.head()
# Out:
#                                              address  \
# 0                                9th Mile, Kalimpong
# 1                 New Kalimati Road, Kasidih, Sakchi
# 2  Opposite Nagarpalika, Near Pushkarna Bera, Pos...
# 3      11-3-11 Veterinary Hospital road,Ramarao peta
# 4                   Near Fort First Gate, Dhibbapara
#
#                          area        city  cleartrip_seller_rating country  \
# 0       Rishi Road-Highway 12   Kalimpong                      NaN   INDIA
# 1                         NaN  Jamshedpur                      NaN   INDIA
# 2                         NaN   Jaisalmer                      NaN   INDIA
# 3                 Cinema Road    Kakinada                      NaN   INDIA
# 4  Near Jaisalmer Golden Fort   Jaisalmer                      NaN   INDIA
#
#    crawl_date                                  hotel_description  \
# 0  2016-08-16  Hotel Jiwan Jyoti, Kalimpong is an ultimate st...
# 1  2016-08-16  Retire to the beautiful rooms of OYO Premium K...
# 2  2016-08-16  OYO Rooms Bera Road in Jaisalmer has a royal c...
# 3  2016-08-16  Situated in quite part of the city yet close t...
# 4  2016-08-16  Hotel Gorakh Haveli, Jaisalmer, with hospitali...
#
#                                     hotel_facilities hotel_star_rating  \
# 0  Travel:Travel Desk|Parking|Free Parking|Person...      1 Star hotel
# 1  Food &amp; Beverage:Bar|Restaurant|Basics:Inte...      3 Star hotel
# 2  Basics:Internet|Air Conditioning|Doorman|House...      3 Star hotel
# 3  Food &amp; Beverage:Bar|Restaurant|Coffee Shop...      3 Star hotel
# 4  Basics:Internet|Air Conditioning|Non-Smoking R...      3 Star hotel
#
#    image_count                                         image_urls  \
# 0           10  http://ui.cltpstatic.com/places/hotels/3345/33...
# 1           10  http://ui.cltpstatic.com/places/hotels/1358/13...
# 2           10  http://ui.cltpstatic.com/places/hotels/1358/13...
# 3           12  http://ui.cltpstatic.com/places/hotels/1324/13...
# 4           17  http://ui.cltpstatic.com/places/hotels/3540/35...
#
#                                 landmark   latitude  \
# 0       Rishi Road-Highway 12, Kalimpong        NaN
# 1                           , Jamshedpur  22.801045
# 2                            , Jaisalmer  26.903590
# 3                  Cinema Road, Kakinada  16.964426
# 4  Near Jaisalmer Golden Fort, Jaisalmer  26.916311
#
#                      locality  longitude  \
# 0       Rishi Road-Highway 12        NaN
# 1                         NaN  86.210080
# 2                         NaN  70.912410
# 3                 Cinema Road  82.231619
# 4  Near Jaisalmer Golden Fort  70.908312
#
#                                              pageurl  property_id  \
# 0  http://www.cleartrip.com/hotels/details/334539...       334539
# 1  http://www.cleartrip.com/hotels/details/135835...      1358354
# 2  http://www.cleartrip.com/hotels/details/135880...      1358804
# 3  http://www.cleartrip.com/hotels/details/132447...      1324474
# 4  http://www.cleartrip.com/hotels/details/354020...       354020
#
#                           property_name property_type    province  \
# 0                     Hotel Jivan Jyoti         Hotel   Kalimpong
# 1  OYO Premium Kalimati Road Jamshedpur           NaN  Jamshedpur
# 2                   OYO Rooms Bera Road           NaN   Jaisalmer
# 3          Grand Kakinada by GRT Hotels         Hotel    Kakinada
# 4                   Hotel Gorakh Haveli         Hotel   Jaisalmer
#
#                          qts room_area  room_count  \
# 0  2016-08-16 14:46:30 +0000       NaN           9
# 1  2016-08-16 14:46:30 +0000       NaN          15
# 2  2016-08-16 14:46:30 +0000       NaN          15
# 3  2016-08-16 14:46:30 +0000       NaN          85
# 4  2016-08-16 14:46:30 +0000       NaN          17
#
#                                      room_facilities         room_type  \
# 0       Toiletries | Luggage Rack | Private Bathroom     Standard Room
# 1  Air Conditioning | Television | Toiletries Int...      Premium Room
# 2  Air Conditioning | Television | Refrigerator I...  Standard Room AC
# 3  Air Conditioning| Television| Iron| Mini Bar| ...     Business Room
# 4  Television| Internet / Broadband| Telephone| W...            Deluxe
#
#                             similar_hotel                  sitename  \
# 0              380320|42243|719031|731828  http://www.cleartrip.com
# 1  1358306|1358328|708981|1358308|1358324  http://www.cleartrip.com
# 2     1324136|714826|378862|709231|315577  http://www.cleartrip.com
# 3      711094|713285|711106|713171|319938  http://www.cleartrip.com
# 4     1324136|714826|378862|709231|315577  http://www.cleartrip.com
#
#            state  tad_review_count  tad_review_rating  \
# 0     WestBengal               NaN                NaN
# 1      Jharkhand               NaN                NaN
# 2      Rajasthan               NaN                NaN
# 3  AndhraPradesh              47.0                4.5
# 4      Rajasthan              86.0                4.0
#
#                               tad_stay_review_rating  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Location::4.5|Rooms::4.5|Service::4.5|Value::4...
# 4  Location::4.5|Rooms::4.0|Service::4.0|Value::4...
#
#   tripadvisor_seller_rating                           uniq_id
# 0                       NaN  661f071f6cf68a7b0e79cc97dd1b38c8
# 1                       NaN  06e5a2147666c30db4257c5faa43700e
# 2                       NaN  3d8d4724ea98e060610864bd6950179b
# 3                    Top 1%  839ca0df66d13f30a8e273080771600b
# 4                   Top 31%  97ec6c27ce6cbfa24869473a15d14ef2

# %%
df_kar = dfc[ dfc["state"]=="Karnataka" ]

# %%
df_kar.dropna(subset=["latitude","room_facilities","hotel_star_rating","hotel_description"],inplace=True)
# Out:
# /mnt/A02ECA772ECA464E/workspace/Python/jypterbook/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_kar.head(2)
# Out:
#                                                 address              area  \
# 44    Malalli Cross, N Belathur, Antharasanthe, H.D....  Kabini Backwater
# 1210      Prafulla Enclave, Halady Road, Kundapur Udupi        Kodi Beach
#
#            city  cleartrip_seller_rating country  crawl_date  \
# 44       Kabini                      NaN   INDIA  2016-08-16
# 1210  Kundapura                      NaN   INDIA  2016-08-16
#
#                                       hotel_description  \
# 44    Kaav Safari Lodge, Kabini is a luxury jungle h...
# 1210  Meridian Bay Resort & Spa is one of the Kundap...
#
#                                        hotel_facilities hotel_star_rating  \
# 44    Basics:Internet|Air Conditioning|Doorman|Expre...      2 Star hotel
# 1210  Food &amp; Beverage:Bar|Restaurant|Coffee Shop...      4 Star hotel
#
#       image_count                                         image_urls  \
# 44             14  http://ui.cltpstatic.com/places/hotels/7087/70...
# 1210           44  http://ui.cltpstatic.com/places/hotels/9561/95...
#
#                       landmark   latitude          locality  longitude  \
# 44    Kabini Backwater, Kabini  11.957905  Kabini Backwater  76.249706
# 1210     Kodi Beach, Kundapura  13.593025        Kodi Beach  74.713244
#
#                                                 pageurl  property_id  \
# 44    http://www.cleartrip.com/hotels/details/708747...       708747
# 1210  http://www.cleartrip.com/hotels/details/956176...       956176
#
#                   property_name property_type   province  \
# 44            Kaav Safari Lodge         Lodge     Kabini
# 1210  Meridian Bay Resort & Spa        Resort  Kundapura
#
#                             qts   room_area  room_count  \
# 44    2016-08-16 14:46:30 +0000         NaN           4
# 1210  2016-08-16 14:46:30 +0000  288.0sqft.          52
#
#                                         room_facilities      room_type  \
# 44    Air Conditioning| Internet / Broadband| Iron| ...  Superior Room
# 1210  Air Conditioning| Television| Internet / Broad...      Club Room
#
#       similar_hotel                  sitename      state  tad_review_count  \
# 44    723561|731835  http://www.cleartrip.com  Karnataka             158.0
# 1210         423549  http://www.cleartrip.com  Karnataka              70.0
#
#       tad_review_rating                             tad_stay_review_rating  \
# 44                  5.0  Location::4.5|Rooms::5.0|Service::5.0|Value::4...
# 1210                4.5  Location::4.0|Rooms::5.0|Service::4.5|Value::4...
#
#      tripadvisor_seller_rating                           uniq_id
# 44                     Top 22%  e82537e062e87a4eda7a70db20650efa
# 1210                    Top 1%  30bf9680cb9cabcef882e0d048dfb684

# %%
df_kar.drop(axis=1,inplace=True,columns=["country","cleartrip_seller_rating","crawl_date","landmark","image_count","locality","pageurl","property_id","province","qts","similar_hotel","pageurl","sitename","tripadvisor_seller_rating","uniq_id"])

# %%
df_kar.count()
# Out:
# address                   128
# area                      128
# city                      128
# hotel_description         128
# hotel_facilities          127
# hotel_star_rating         128
# image_urls                128
# latitude                  128
# longitude                 128
# property_name             128
# property_type              44
# room_area                   6
# room_count                128
# room_facilities           128
# room_type                 128
# state                     128
# tad_review_count           94
# tad_review_rating          94
# tad_stay_review_rating     94
# dtype: int64

# %%
df_kar.head()
# Out:
#                                                 address               area  \
# 44    Malalli Cross, N Belathur, Antharasanthe, H.D....   Kabini Backwater
# 1210      Prafulla Enclave, Halady Road, Kundapur Udupi         Kodi Beach
# 1418  Toodalli Village, Yedthare Post, Shiroor Check...           Kundapur
# 1474  BH Road, Kandavara Village, Opp to Muncipal Wa...           Kundapur
# 1479                      Near Kollur Mookambika Temple  Mookambika Temple
#
#            city                                  hotel_description  \
# 44       Kabini  Kaav Safari Lodge, Kabini is a luxury jungle h...
# 1210  Kundapura  Meridian Bay Resort & Spa is one of the Kundap...
# 1418  Kundapura  Wild woods spa is a Botanical resort set on th...
# 1474  Kundapura  Pratham Inn & Resort is Surrounded by lush gre...
# 1479     Kollur  Aswathi Tourist Home, Kollur, Karnataka, greet...
#
#                                        hotel_facilities hotel_star_rating  \
# 44    Basics:Internet|Air Conditioning|Doorman|Expre...      2 Star hotel
# 1210  Food &amp; Beverage:Bar|Restaurant|Coffee Shop...      4 Star hotel
# 1418  Food &amp; Beverage:Restaurant|Personal Servic...      4 Star hotel
# 1474  Basics:Internet|Air Conditioning|Food &amp; Be...      3 Star hotel
# 1479  Food &amp; Beverage:Restaurant|Personal Servic...      2 Star hotel
#
#                                              image_urls   latitude  longitude  \
# 44    http://ui.cltpstatic.com/places/hotels/7087/70...  11.957905  76.249706
# 1210  http://ui.cltpstatic.com/places/hotels/9561/95...  13.593025  74.713244
# 1418  http://ui.cltpstatic.com/places/hotels/4235/42...  13.942949  74.649429
# 1474  http://ui.cltpstatic.com/places/hotels/7432/74...  13.632160  74.736389
# 1479  http://ui.cltpstatic.com/places/hotels/7154/71...  13.868707  74.812729
#
#                                         property_name property_type  \
# 44                                  Kaav Safari Lodge         Lodge
# 1210                        Meridian Bay Resort & Spa        Resort
# 1418                          Wild Woods Spa & Resort        Resort
# 1474  VITS Pratham Luxury Business Hotel & Water Park         Hotel
# 1479                             Aswathi Tourist Home           NaN
#
#        room_area  room_count  \
# 44           NaN           4
# 1210  288.0sqft.          52
# 1418         NaN          10
# 1474         NaN          35
# 1479         NaN          24
#
#                                         room_facilities  \
# 44    Air Conditioning| Internet / Broadband| Iron| ...
# 1210  Air Conditioning| Television| Internet / Broad...
# 1418  Air Conditioning| Television| Telephone | Hot ...
# 1474  Air Conditioning| Telephone | Television | Pri...
# 1479  Television| Safe | Air Conditioning | Private ...
#
#                              room_type      state  tad_review_count  \
# 44                       Superior Room  Karnataka             158.0
# 1210                         Club Room  Karnataka              70.0
# 1418  1 Bedroom Villa with Plunge Pool  Karnataka             300.0
# 1474                 Super Deluxe Room  Karnataka               2.0
# 1479                    Double Room AC  Karnataka              16.0
#
#       tad_review_rating                             tad_stay_review_rating
# 44                  5.0  Location::4.5|Rooms::5.0|Service::5.0|Value::4...
# 1210                4.5  Location::4.0|Rooms::5.0|Service::4.5|Value::4...
# 1418                4.5  Location::4.5|Rooms::5.0|Service::4.5|Value::4...
# 1474                3.5  Location::0.0|Rooms::0.0|Service::0.0|Value::0...
# 1479                2.0  Location::2.5|Rooms::2.5|Service::2.0|Value::2...
