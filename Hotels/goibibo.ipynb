# %%
import pandas as pd

# %%
df = pd.read_csv("goibibo.csv")

# %%
# df.drop(['crawl_date','guest_recommendation','site_review_count','site_review_rating','site_stay_review_rating','sitename','uniq_id','review_count_by_category','query_time_stamp','qts','similar_hotel','province','property_id','pageurl','locality'], axis=1, inplace=True)
# df.drop(['guest_recommendation','hotel_brand','similar_hotel','site_review_count','site_review_rating','site_stay_review_rating','sitename','uniq_id','room_area','review_count_by_category','query_time_stamp','qts','pageurl','point_of_interest','image_count','hotel_category','hotel_star_rating','property_id','property_name','province','additional_info','locality','area','country'], axis=1, inplace=True)

# %%
df.dropna(inplace=True)
pd.set_option('display.max_columns', 50)
df.head()
# Out:
#                                        additional_info  \
# 23                             Room Service|Restaurant
# 92       Room Service|Gym/Spa|Swimming Pool|Restaurant
# 137  Room Service|Internet Access|Restaurant|Free I...
# 218  Room Service|Internet Access|Gym/Spa|Swimming ...
# 252                    Room Service|Gym/Spa|Restaurant
#
#                                                address                 area  \
# 23                     Nagalore road  Opp petrol bunk,    Yercaud Main Town
# 92   Plot no. 15, 24, 25 and 26, Survey no. 64, Sec...         Hi-Tech City
# 137  PNG ROAD,NEAR PALZOR NAMGYAL GIRLS HIGH SCHOOL...  Paljor Stadium Road
# 218     S.No. 127, Malgund, Nr. Ganapatipule,Ratnagiri      Malgund Village
# 252           1/498, Calvetty Road, Fort Kochi, Cochin           Fort Kochi
#
#             city country  crawl_date  guest_recommendation  \
# 23       Yercaud   India  2016-07-24                 100.0
# ...

# %%
dff=df[["additional_info","property_type","room_area","room_facilities"]]

# %%
dff.count()
# Out:
# additional_info    145
# property_type      145
# room_area          145
# room_facilities    145
# dtype: int64

# %%
dff=dff.iloc[:128]

# %%
dff.count()
# Out:
# additional_info    128
# property_type      128
# room_area          128
# room_facilities    128
# dtype: int64

# %%
dff.head()
# Out:
#                                        additional_info property_type  \
# 23                             Room Service|Restaurant   Guest House
# 92       Room Service|Gym/Spa|Swimming Pool|Restaurant         Hotel
# 137  Room Service|Internet Access|Restaurant|Free I...        Resort
# 218  Room Service|Internet Access|Gym/Spa|Swimming ...        Resort
# 252                    Room Service|Gym/Spa|Restaurant         Hotel
#
#             room_area                                    room_facilities
# 23     14 X 14 Sq.ft.  Room Service |Telephone|Newspapers|Mineral Wat...
# 92     19 X 19 Sq.ft.  Basic Bathroom Amenities|Cable / Satellite / P...
# 137    12 X 15 Sq.ft.  Room Service |Air Conditioning |Alarm Clock|Ba...
# 218  675 X 675 Sq.ft.  Air Conditioning |Basic Bathroom Amenities|Cab...
# 252    12 X 12 Sq.ft.  Air Conditioning |Balcony / Terrace|Basic Bath...

# %%
df_p =  df[['city','state']]

# %%
# df_p.loc[:,"cityCap"] = df_p["city"].str.upper().str.strip()
df_pd = df_p.drop_duplicates(subset='city',keep='last')

# %%
df_pd.loc[:,"latitude"]=0.000
df_pd.loc[:,"longitude"]=0.00
df_pd.head()
# Out:
#             city          state  latitude  longitude
# 23       Yercaud     Tamil Nadu       0.0        0.0
# 118       Almora    Uttarakhand       0.0        0.0
# 168     Varanasi  Uttar Pradesh       0.0        0.0
# 218  Ganpatipule    Maharashtra       0.0        0.0
# 316        Patna          Bihar       0.0        0.0

# %%
import requests
address = Template('$city,$state')
def frame(source):
    for index, row in source.iterrows():
        place = row.values
        address = place[0]+ ',' + place[1]   
#         response = requests.get('https://maps.googleapis.com/maps/api/geocode/json?address='+address+'&key=AIzaSyAyuakM26bbp3raXmbCDw4_k1oY6cOgvWA')
#         data = response.json()
       
#         print(data["results"][0]["geometry"]["location"])
        location = data["results"][0]["geometry"]["location"]
        
        df_pd.at[index, 'latitude'] = location["lat"]
        df_pd.at[index, 'longitude'] = location["lng"]

# %%
frame(df_pd)

# %%
df_state = df_pd[["state"]]

# %%
df_state = df_state.drop_duplicates(subset="state",keep="last")

# %%
df_state.sort_values('state',inplace=True)
df_state = df_state.reset_index(drop=True)
# df_state = df_state.drop(axis=1,columns=["index"])

df_state.index+=1

# %%
def frame_to_sql(source):
    f = open('state.sql', 'w')
    f.write('INSERT INTO state ('+ 'id,' + str(', '.join(source.columns)) + ') VALUES ')
    f.write('\n')
    count=1
    for index, row in source.iterrows(): 
        lst = np.insert(row.values, 0, index, axis=0)
        f.write( str(tuple(lst)))
        f.write(';') if count==len(source) else f.write(',\n')
        count=count+1
        
    f.close()

# %%
frame_to_sql(df_state)

# %% [markdown]
# df_pd_c = df_pd

# %% [markdown]
# df_pd = df_pd_c

# %%
df_pd.head()
# Out:
#             city          state   latitude  longitude
# 23       Yercaud     Tamil Nadu  11.775251  78.209258
# 118       Almora    Uttarakhand  29.589241  79.646666
# 168     Varanasi  Uttar Pradesh  25.317645  82.973914
# 218  Ganpatipule    Maharashtra  17.148866  73.272695
# 316        Patna          Bihar  25.594095  85.137564

# %%
# df_state["state_id"]= df_state.index
# df_state.head()
# Out:
#                          state  state_id
# 1  Andaman and Nicobar Islands         1
# 2               Andhra Pradesh         2
# 3                        Assam         3
# 4                        Bihar         4
# 5                        Delhi         5

# %%
df_merge = pd.merge(df_pd, df_state, on='state')

# %%
# df_merge.drop(axis=1,columns=['state'],inplace=True)

# %%
df_merge.index += 1 
df_merge.head()
# Out:
#           city       state   latitude  longitude
# 1      Yercaud  Tamil Nadu  11.775251  78.209258
# 2  kanyakumari  Tamil Nadu   8.088306  77.538451
# 3         Ooty  Tamil Nadu  11.410204  76.695032
# 4   Kodaikanal  Tamil Nadu  10.238114  77.489182
# 5   Masinagudi  Tamil Nadu  11.572177  76.642715

# %%
def frame_to_sql(source):
    f = open('city.sql', 'w')
    f.write('INSERT INTO city ('+ 'id,' + str(', '.join(source.columns)) + ') VALUES ')
    f.write('\n')
    count=1
    for index, row in source.iterrows(): 
        lst = np.insert(row.values, 0, index, axis=0)
        f.write( str(tuple(lst)))
        f.write(';') if count==len(source) else f.write(',\n')
        count=count+1
        
    f.close()

# %%
frame_to_sql(df_merge)

# %%
df_merge.loc[:,"city_id"]= df_merge.index
df_merge.head()
# Out:
#           city       state   latitude  longitude  city_id
# 1      Yercaud  Tamil Nadu  11.775251  78.209258        1
# 2  kanyakumari  Tamil Nadu   8.088306  77.538451        2
# 3         Ooty  Tamil Nadu  11.410204  76.695032        3
# 4   Kodaikanal  Tamil Nadu  10.238114  77.489182        4
# 5   Masinagudi  Tamil Nadu  11.572177  76.642715        5

# %%
df_city = df_merge[["city_id","city"]]

# %%
df_new = pd.merge(df, df_city, on='city')

# %%
df_new.head()
# Out:
#                                  additional_info  \
# 0                        Room Service|Restaurant
# 1  Room Service|Gym/Spa|Swimming Pool|Restaurant
# 2          Room Service|Restaurant|Free Internet
# 3        Room Service|Internet Access|Restaurant
# 4        Room Service|Internet Access|Restaurant
#
#                                              address               area  \
# 0                    Nagalore road  Opp petrol bunk,  Yercaud Main Town
# 1  Plot no. 15, 24, 25 and 26, Survey no. 64, Sec...       Hi-Tech City
# 2  HNo. 1-11-254 And 255, Srinivas Naik Estate, S...           Begumpet
# 3  Plot 60,61, Green Hamlet, Shilpa Park, Near to...       Hi-Tech City
# 4  Hotel Majestica 2-41/2/A, Sy.4, 2nd Floor, Pav...       Hi-Tech City
#
#         city country     hotel_brand hotel_category  \
# 0    Yercaud   India  Leisure Hotels        regular
# 1  Hyderabad   India           Avasa        regular
# 2  Hyderabad   India        Executel        regular
# ...

# %%
df_new.drop(axis=1,columns=["city","country","state"],inplace=True)

# %%
df_new.head()
# Out:
#                                  additional_info  \
# 0                        Room Service|Restaurant
# 1  Room Service|Gym/Spa|Swimming Pool|Restaurant
# 2          Room Service|Restaurant|Free Internet
# 3        Room Service|Internet Access|Restaurant
# 4        Room Service|Internet Access|Restaurant
#
#                                              address               area  \
# 0                    Nagalore road  Opp petrol bunk,  Yercaud Main Town
# 1  Plot no. 15, 24, 25 and 26, Survey no. 64, Sec...       Hi-Tech City
# 2  HNo. 1-11-254 And 255, Srinivas Naik Estate, S...           Begumpet
# 3  Plot 60,61, Green Hamlet, Shilpa Park, Near to...       Hi-Tech City
# 4  Hotel Majestica 2-41/2/A, Sy.4, 2nd Floor, Pav...       Hi-Tech City
#
#       hotel_brand hotel_category  \
# 0  Leisure Hotels        regular
# 1           Avasa        regular
# 2        Executel        regular
# 3       FabHotels        regular
# 4       FabHotels        regular
#
# ...
